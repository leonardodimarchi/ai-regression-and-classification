# %% [markdown]
# # Grupo
#
# | RA | Nome |
# | :---------------- | :------: |
# | 200109 | Leonardo Dimarchi Souza da Cruz |
# | 200359 | Luiz Fernando Toquetto |
# | 224072 | Vinícius Martins Granso |

# %% [markdown]
# # Dataset
#
# O dataset escolhido foi o [House Sales in King County, USA](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction/data). Ele possui preços de casas a venda entre os anos de 2014 e 2015 em King County nos estados unidos.

# %%
import pandas as pd

# Lendo o dataset
dataset_original = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# # Análise Exploratória de Dados (EDA)

# %% [markdown]
# ### Analise dos atributos

# %%
# Exibindo as dimensões do dataset
print(dataset_original.shape)

# Exibindo as 5 primeiras linhas do dataset
display(dataset_original.head())

# Exibindo algumas estatísticas dos atributos
dataset_original.describe()
# Out:
# (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# Com a visualização do dataset, iremos verificar as colunas para entender o que cada uma significa, com a ajuda do fórum de discussões do Kaggle para as colunas menos intuitivas:
#
#
# - **ID**: Identificador da casa
# - **Date**: Data da venda
# - **Price**: Preço da casa em dólares
# - **Bedrooms**: Quantidade de quartos
# - **Bathrooms**: Quantidade de banheiros (valores 0.5 significam lavabos)
# - **Sqft_living**: Metros quadrados da casa
# - **Sqft_lot**: Metros quadrados do lote
# - **Floors**: Quantidade de andares da casa
# - **Waterfront**: Diz se a casa está a beira-mar (0 e 1)
# - **View**: Indica a qualidade da vista da propriedade, de 0 a 4.
# - **Condition**: Condição atual da casa, de 1 a 5. Quanto maior, melhor conservada
# - **Grade**:  Nota da casa após construção, de 1 a 13. Quanto maior, melhor
# - **Sqft_above**: Metros quadrados considerando andares que estão acima do térreo
# - **Sqft_basement**: Metros quadrados do porão
# - **Yr_built**: Ano de construção
# - **Yr_renovated**: Ano da última renovação
# - **Zipcode**: CEP
# - **Lat**: Latitude
# - **Long**: Longitude
# - **Sqft_living15**: Média de metros quadrados da casa dos 15 vizinhos mais próximos
# - **Sqft_lot15**: Média de metros quadrados do lote dos 15 vizinhos mais próximos

# %% [markdown]
# ### Verificação de valores ausentes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

soma_de_nulos_por_atributo = dataset_original.isnull().sum();
print(soma_de_nulos_por_atributo)
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Não existem valores nulos em nenhum dos atributos deste dataset.

# %% [markdown]
# # Pré-processamento
#
# ### Correlação

# %%
# Realizando a cópia do dataset para manter a cópia original 
dataset = dataset_original.copy()

# Convertendo o atributo de data do formato 20141013T000000 para datetime,
# assim representando as datas de maneira numérica para que seja possível calcular a correlação
dataset['date'] = pd.to_datetime(dataset['date'], format='%Y%m%dT%H%M%S')

# Calculando o mapa de correlação
mapa_de_correlacao = dataset.corr()

# Plotando o mapa de correlação
plt.subplots(figsize=(17,14))
sns.heatmap(mapa_de_correlacao, annot=True, linewidths=0.5, linecolor="Black", fmt="1.1f")
plt.title("Correlação dos atributos",fontsize=30)
plt.show()

# %% [markdown]
# Plotamos o heatmap da correlação dos atributos para identificar quais são mais relevantes para determinar o preço da casa.
# Removeremos alguns desses atributos na próxima etapa.
#
# Por hora, vamos ver a relação dos atributos com maior correlação.

# %%
sns.pairplot(dataset, x_vars=['sqft_living','grade', 'sqft_above', 'sqft_living15'], y_vars='price', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# ### Remoção de atributos

# %%
# Removendo os atributos 
colunas_para_remover = ['id', 'long', 'condition', 'date']
dataset_pos_remocao_colunas = dataset.drop(colunas_para_remover, axis=1)

# Exibindo as dimensões do dataset
print(dataset_pos_remocao_colunas.shape)
# Out:
# (21613, 17)

# %% [markdown]
# Dado o resultado do heatmap, removemos os seguintes atributos:
#
# - Id
# - Data
# - Longitude
# - Condição

# %% [markdown]
# ### Outliers

# %%
# Box plot do dataset
dataset_pos_remocao_colunas.boxplot(figsize=(20,15))

# Ordenando
dataset_ordenado_preco = dataset_pos_remocao_colunas.sort_values(by=['price'], ascending=False)
display(dataset_ordenado_preco.head(25))
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7252   7700000.0         6       8.00        12050     27600     2.5
# 3914   7062500.0         5       4.50        10040     37325     2.0
# 9254   6885000.0         6       7.75         9890     31374     2.0
# 4411   5570000.0         5       5.75         9200     35069     2.0
# 1448   5350000.0         5       5.00         8000     23985     2.0
# 1315   5300000.0         6       6.00         7390     24829     2.0
# 1164   5110800.0         5       5.25         8010     45517     2.0
# 8092   4668000.0         5       6.75         9640     13068     1.0
# 2626   4500000.0         5       5.50         6640     40014     2.0
# 8638   4489000.0         4       3.00         6430     27517     2.0
# 12370  4208000.0         5       6.00         7440     21540     2.0
# 4149   4000000.0         4       5.50         7080     16573     2.0
# 2085   3850000.0         4       4.25         5770     21300     2.0
# 19017  3800000.0         3       4.25         5510     35000     2.0
# 7035   3800000.0         5       5.50         7050     42840     1.0
# 16302  3710000.0         4       3.50         5550     28078     2.0
# 6508   3650000.0         6       4.75         5480     19401     1.5
# 18482  3650000.0         5       3.75         5020      8694     2.0
# 15255  3640900.0         4       3.25         4830     22257     2.0
# 19148  3635000.0         5       6.00         5490     19897     2.0
# 2864   3600000.0         3       3.25         5020     12431     2.0
# 21576  3567000.0         5       4.50         4850     10584     2.0
# 5880   3418800.0         5       5.00         5450     20412     2.0
# 7989   3400000.0         3       4.50         5230     17826     2.0
# 10446  3400000.0         4       4.00         4260     11765     2.0
#
#        waterfront  view  grade  sqft_above  sqft_basement  yr_built  \
# 7252            0     3     13        8570           3480      1910
# 3914            1     2     11        7680           2360      1940
# 9254            0     4     13        8860           1030      2001
# 4411            0     0     13        6200           3000      2001
# 1448            0     4     12        6720           1280      2009
# 1315            1     4     12        5000           2390      1991
# 1164            1     4     12        5990           2020      1999
# 8092            1     4     12        4820           4820      1983
# 2626            1     4     12        6350            290      2004
# 8638            0     0     12        6430              0      2001
# 12370           0     0     12        5550           1890      2003
# 4149            0     0     12        5760           1320      2008
# 2085            1     4     11        5770              0      1980
# 19017           0     4     13        4910            600      1997
# 7035            0     2     13        4320           2730      1978
# 16302           0     2     12        3350           2200      2000
# 6508            1     4     11        3910           1570      1936
# 18482           0     1     12        3970           1050      2007
# 15255           1     4     11        4830              0      1990
# 19148           0     0     12        5490              0      2005
# 2864            1     4     10        3420           1600      1941
# 21576           1     4     10        3540           1310      2007
# 5880            0     0     11        5450              0      2014
# 7989            1     4     10        3740           1490      2005
# 10446           0     0     11        3280            980      1939
#
#        yr_renovated  zipcode      lat  sqft_living15  sqft_lot15
# 7252           1987    98102  47.6298           3940        8800
# 3914           2001    98004  47.6500           3930       25449
# 9254              0    98039  47.6305           4540       42730
# 4411              0    98039  47.6289           3560       24345
# 1448              0    98004  47.6232           4600       21750
# 1315              0    98040  47.5631           4320       24619
# 1164              0    98033  47.6767           3430       26788
# 8092           2009    98040  47.5570           3270       10454
# 2626              0    98155  47.7493           3030       23408
# 8638              0    98004  47.6208           3720       14592
# 12370             0    98006  47.5692           4740       19329
# 4149              0    98039  47.6151           3140       15996
# 2085              0    98040  47.5850           4620       22748
# 19017             0    98177  47.7296           3430       45302
# 7035              0    98004  47.6229           5070       20570
# 16302             0    98039  47.6395           2980       19602
# 6508              0    98105  47.6515           3510       15810
# 18482             0    98004  47.6146           4190       11275
# 15255             0    98039  47.6409           3820       25582
# 19148             0    98039  47.6165           2910       17600
# 2864           2002    98144  47.5925           3680       12620
# 21576             0    98008  47.5943           3470       18270
# 5880              0    98039  47.6209           3160       17825
# 7989              0    98040  47.5348           3670       17826
# 10446          2010    98112  47.6380           4260       10408

# %% [markdown]
# Através da visualização de boxplot, pudemos verificar que existem alguns valores muito altos para preços de casa se comparado com a média. Portanto, realizamos a ordenação dos dados com base no preço para visualizarmos as linhas de preço mais alto. Com isso, vimos que esses outliers podem ser mantidos pois fazem sentido para nossa solução, são casas que tem um preço elevado, mas também possuem muito espaço e notas altas.

# %% [markdown]
# ### Separação dos dados de treino/teste

# %%
from sklearn.model_selection import train_test_split

# Separando o target e os outros atributos
target = dataset_pos_remocao_colunas['price']
X = dataset_pos_remocao_colunas.drop(['price'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, target, test_size = 0.3, random_state=1)

# %% [markdown]
# # Modelos

# %% [markdown]
# ### Regressão linear

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.metrics import r2_score

# Gerando o normalizador
normalizer = preprocessing.Normalization()
normalizer.adapt(X_train)

# Criando o modelo com o normalizador e uma camada com um único perceptron
model = keras.Sequential([
    normalizer,
    layers.Dense(1)
])

# Exibindo um resumo do modelo
model.summary()

# Configurando o modelo para utilizar o Adam durante gradiente descendente, utilizando erro quadrático médio para calculo de loss
model.compile(optimizer=tf.optimizers.Adam(learning_rate=100), loss='mean_squared_error')

# Treino com 100 épocas e 20% dos dados para calculo de loss
history = model.fit(
    X_train, y_train,
    epochs=100,
    validation_split=0.2,
    verbose=1
)

# Plotando o gráfico de loss para treino e teste com base na época
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Épocas')
    plt.ylabel('Erro')
    plt.legend()
    plt.grid(True)

plot_loss(history)

# Teste
y_pred = model.predict(X_test)

# Visualizando a métrica R^2, quanto mais próximo de 1, melhor o ajuste do modelo aos dados
r2 = r2_score(y_test, y_pred)
print(f'R-squared (R²): {r2}')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normaliza  (None, 16)                33
#  tion)
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 50 (204.00 Byte)
# Trainable params: 17 (68.00 Byte)
# Non-trainable params: 33 (136.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 433/433 [==============================] - 1s 1ms/step - loss: 352722681856.0000 - val_loss: 320382959616.0000
# Epoch 2/100
# 433/433 [==============================] - 0s 1ms/step - loss: 280287346688.0000 - val_loss: 262932611072.0000
# Epoch 3/100
# 433/433 [==============================] - 0s 1ms/step - loss: 234905780224.0000 - val_loss: 222303862784.0000
# Epoch 4/100
# 433/433 [==============================] - 0s 1ms/step - loss: 199167098880.0000 - val_loss: 188989472768.0000
# Epoch 5/100
# 433/433 [==============================] - 1s 1ms/step - loss: 169048915968.0000 - val_loss: 160881754112.0000
# Epoch 6/100
# 433/433 [==============================] - 0s 1ms/step - loss: 143291121664.0000 - val_loss: 137177399296.0000
# Epoch 7/100
# 433/433 [==============================] - 0s 1ms/step - loss: 121298288640.0000 - val_loss: 116744183808.0000
# Epoch 8/100
# 433/433 [==============================] - 0s 1ms/step - loss: 102576152576.0000 - val_loss: 99625861120.0000
# Epoch 9/100
# 433/433 [==============================] - 0s 1ms/step - loss: 86807519232.0000 - val_loss: 85283356672.0000
# Epoch 10/100
# 433/433 [==============================] - 0s 1ms/step - loss: 73792978944.0000 - val_loss: 73548890112.0000
# Epoch 11/100
# 433/433 [==============================] - 0s 1ms/step - loss: 63224094720.0000 - val_loss: 64181194752.0000
# Epoch 12/100
# 433/433 [==============================] - 0s 1ms/step - loss: 54902386688.0000 - val_loss: 56941678592.0000
# Epoch 13/100
# 433/433 [==============================] - 0s 1ms/step - loss: 48599134208.0000 - val_loss: 51563700224.0000
# Epoch 14/100
# 433/433 [==============================] - 0s 1ms/step - loss: 44053217280.0000 - val_loss: 47758630912.0000
# Epoch 15/100
# 433/433 [==============================] - 0s 1ms/step - loss: 40922701824.0000 - val_loss: 45304057856.0000
# Epoch 16/100
# 433/433 [==============================] - 0s 1ms/step - loss: 38947422208.0000 - val_loss: 43781545984.0000
# Epoch 17/100
# 433/433 [==============================] - 1s 1ms/step - loss: 37820256256.0000 - val_loss: 42939346944.0000
# Epoch 18/100
# 433/433 [==============================] - 1s 1ms/step - loss: 37248282624.0000 - val_loss: 42527215616.0000
# Epoch 19/100
# 433/433 [==============================] - 1s 1ms/step - loss: 37006626816.0000 - val_loss: 42418925568.0000
# Epoch 20/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36920131584.0000 - val_loss: 42371575808.0000
# Epoch 21/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36882636800.0000 - val_loss: 42288685056.0000
# Epoch 22/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36874035200.0000 - val_loss: 42355650560.0000
# Epoch 23/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36864614400.0000 - val_loss: 42307633152.0000
# Epoch 24/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36852690944.0000 - val_loss: 42307940352.0000
# Epoch 25/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36870422528.0000 - val_loss: 42254225408.0000
# Epoch 26/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36842123264.0000 - val_loss: 42397413376.0000
# Epoch 27/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36854910976.0000 - val_loss: 42332340224.0000
# Epoch 28/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36857225216.0000 - val_loss: 42248380416.0000
# Epoch 29/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36868104192.0000 - val_loss: 42224521216.0000
# Epoch 30/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36863741952.0000 - val_loss: 42215243776.0000
# Epoch 31/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36867923968.0000 - val_loss: 42217291776.0000
# Epoch 32/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36851253248.0000 - val_loss: 42205454336.0000
# Epoch 33/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36863926272.0000 - val_loss: 42239062016.0000
# Epoch 34/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36831469568.0000 - val_loss: 42269396992.0000
# Epoch 35/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36854661120.0000 - val_loss: 42237005824.0000
# Epoch 36/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36843999232.0000 - val_loss: 42183774208.0000
# Epoch 37/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36850888704.0000 - val_loss: 42206285824.0000
# Epoch 38/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36861865984.0000 - val_loss: 42265849856.0000
# Epoch 39/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36843683840.0000 - val_loss: 42304598016.0000
# Epoch 40/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36832264192.0000 - val_loss: 42170085376.0000
# Epoch 41/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36853682176.0000 - val_loss: 42225274880.0000
# Epoch 42/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36848111616.0000 - val_loss: 42254835712.0000
# Epoch 43/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36850683904.0000 - val_loss: 42277675008.0000
# Epoch 44/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36863025152.0000 - val_loss: 42206826496.0000
# Epoch 45/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36862722048.0000 - val_loss: 42277748736.0000
# Epoch 46/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36849872896.0000 - val_loss: 42281132032.0000
# Epoch 47/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36871262208.0000 - val_loss: 42232688640.0000
# Epoch 48/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36815441920.0000 - val_loss: 42175397888.0000
# Epoch 49/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36836614144.0000 - val_loss: 42304598016.0000
# Epoch 50/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36840525824.0000 - val_loss: 42354757632.0000
# Epoch 51/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36868096000.0000 - val_loss: 42263691264.0000
# Epoch 52/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36852703232.0000 - val_loss: 42241892352.0000
# Epoch 53/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36867096576.0000 - val_loss: 42287345664.0000
# Epoch 54/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36852199424.0000 - val_loss: 42226085888.0000
# Epoch 55/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36875743232.0000 - val_loss: 42236588032.0000
# Epoch 56/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36846718976.0000 - val_loss: 42193829888.0000
# Epoch 57/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857495552.0000 - val_loss: 42211229696.0000
# Epoch 58/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36849819648.0000 - val_loss: 42229731328.0000
# Epoch 59/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857868288.0000 - val_loss: 42202050560.0000
# Epoch 60/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36865974272.0000 - val_loss: 42241843200.0000
# Epoch 61/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857962496.0000 - val_loss: 42242838528.0000
# Epoch 62/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36870672384.0000 - val_loss: 42241527808.0000
# Epoch 63/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36861333504.0000 - val_loss: 42195775488.0000
# Epoch 64/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36862754816.0000 - val_loss: 42243878912.0000
# Epoch 65/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36860145664.0000 - val_loss: 42226216960.0000
# Epoch 66/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36854571008.0000 - val_loss: 42227089408.0000
# Epoch 67/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36855996416.0000 - val_loss: 42222628864.0000
# Epoch 68/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36834603008.0000 - val_loss: 42173759488.0000
# Epoch 69/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36868284416.0000 - val_loss: 42203803648.0000
# Epoch 70/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36850270208.0000 - val_loss: 42215788544.0000
# Epoch 71/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36849004544.0000 - val_loss: 42269995008.0000
# Epoch 72/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36862615552.0000 - val_loss: 42205880320.0000
# Epoch 73/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36846759936.0000 - val_loss: 42271158272.0000
# Epoch 74/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36859682816.0000 - val_loss: 42232877056.0000
# Epoch 75/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36853231616.0000 - val_loss: 42223476736.0000
# Epoch 76/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36844576768.0000 - val_loss: 42281132032.0000
# Epoch 77/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36864036864.0000 - val_loss: 42223931392.0000
# Epoch 78/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36854964224.0000 - val_loss: 42272882688.0000
# Epoch 79/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36856717312.0000 - val_loss: 42248060928.0000
# Epoch 80/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36860043264.0000 - val_loss: 42224656384.0000
# Epoch 81/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36846387200.0000 - val_loss: 42212552704.0000
# Epoch 82/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857118720.0000 - val_loss: 42200276992.0000
# Epoch 83/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36863442944.0000 - val_loss: 42212610048.0000
# Epoch 84/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36839710720.0000 - val_loss: 42281160704.0000
# Epoch 85/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36870381568.0000 - val_loss: 42267512832.0000
# Epoch 86/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36859113472.0000 - val_loss: 42215813120.0000
# Epoch 87/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36849795072.0000 - val_loss: 42217267200.0000
# Epoch 88/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36868554752.0000 - val_loss: 42214076416.0000
# Epoch 89/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36859711488.0000 - val_loss: 42288816128.0000
# Epoch 90/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36851638272.0000 - val_loss: 42261946368.0000
# Epoch 91/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36846469120.0000 - val_loss: 42239471616.0000
# Epoch 92/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36859961344.0000 - val_loss: 42234990592.0000
# Epoch 93/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36838453248.0000 - val_loss: 42206081024.0000
# Epoch 94/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857774080.0000 - val_loss: 42234179584.0000
# Epoch 95/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36845694976.0000 - val_loss: 42344488960.0000
# Epoch 96/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36855484416.0000 - val_loss: 42254331904.0000
# Epoch 97/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36857413632.0000 - val_loss: 42241826816.0000
# Epoch 98/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36863963136.0000 - val_loss: 42259599360.0000
# Epoch 99/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36855300096.0000 - val_loss: 42259263488.0000
# Epoch 100/100
# 433/433 [==============================] - 0s 1ms/step - loss: 36863418368.0000 - val_loss: 42219941888.0000
# 136/136 [==============================] - 0s 767us/step
# R-squared (R²): 0.6804890254086349

# %% [markdown]
# ### Árvore de decisão

# %%
import sklearn.tree as SKTree
import re as re
from sklearn.metrics import r2_score

# Historico de métricas para treino e teste
history_acc_train = []
history_acc_test = []
profundidade_de_maior_r2 = 1

# Treino e preenchimento do histórico para profundidades de 1 até 15
# Utilizando uma árvore regressora com critério de erro quadrático
for max_depth in range(1,15):
    tree = SKTree.DecisionTreeRegressor(criterion='squared_error', max_depth=max_depth)
    tree = tree.fit(X_train, y_train)

    pred_train = tree.predict(X_train)
    pred_test = tree.predict(X_test)

    r2_train = r2_score(y_train, pred_train)
    r2_test = r2_score(y_test, pred_test)

    history_acc_train.append(r2_train)
    history_acc_test.append(r2_test)

# Exibindo o histórico de métrica R^2 para cada profundidade tanto em treino quanto em teste
plt.plot(history_acc_train)
plt.plot(history_acc_test)
plt.title('Métrica R^2 por profundidade')
plt.ylabel('R^2')
plt.xlabel('Profundidade')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotando a árvore para uma profundidade escolhida
profundidade = 4

# Exibindo a métrica R^2 para a profundidade escolhida
print(history_acc_train[profundidade])
print(history_acc_test[profundidade])

tree = SKTree.DecisionTreeRegressor(criterion='squared_error', max_depth=profundidade)
tree = tree.fit(X_train, y_train)

pred_train = tree.predict(X_train)
pred_test = tree.predict(X_test)

r2_train = r2_score(y_train, pred_train)
r2_test = r2_score(y_test, pred_test)

history_acc_train.append(r2_train)
history_acc_test.append(r2_test)

SKTree.plot_tree(tree, fontsize=8)
# Out:
# 0.7248799550541686
# 0.6703744552831841
# [Text(0.5, 0.9, 'x[7] <= 8.5\nsquared_error = 125294477560.153\nsamples = 17290\nvalue = 537880.615'),
#  Text(0.25, 0.7, 'x[13] <= 47.534\nsquared_error = 38513570102.911\nsamples = 13871\nvalue = 436946.673'),
#  Text(0.125, 0.5, 'x[2] <= 2019.5\nsquared_error = 13597846443.277\nsamples = 5843\nvalue = 315671.12'),
#  Text(0.0625, 0.3, 'x[2] <= 1442.0\nsquared_error = 7328989771.825\nsamples = 3919\nvalue = 274734.092'),
#  Text(0.03125, 0.1, 'squared_error = 5780628096.617\nsamples = 1887\nvalue = 242996.672'),
#  Text(0.09375, 0.1, 'squared_error = 6962836213.8\nsamples = 2032\nvalue = 304206.785'),
#  Text(0.1875, 0.3, 'x[13] <= 47.414\nsquared_error = 16000359491.902\nsamples = 1924\nvalue = 399055.847'),
#  Text(0.15625, 0.1, 'squared_error = 8379499171.619\nsamples = 967\nvalue = 351900.515'),
#  Text(0.21875, 0.1, 'squared_error = 19183653098.615\nsamples = 957\nvalue = 446703.92'),
#  Text(0.375, 0.5, 'x[2] <= 2035.0\nsquared_error = 38152022096.65\nsamples = 8028\nvalue = 525214.368'),
#  Text(0.3125, 0.3, 'x[2] <= 1454.0\nsquared_error = 19639349157.622\nsamples = 5395\nvalue = 461576.082'),
#  Text(0.28125, 0.1, 'squared_error = 14547703794.823\nsamples = 2673\nvalue = 410371.155'),
#  Text(0.34375, 0.1, 'squared_error = 19536195193.308\nsamples = 2722\nvalue = 511859.245'),
#  Text(0.4375, 0.3, 'x[5] <= 0.5\nsquared_error = 50783581724.2\nsamples = 2633\nvalue = 655608.805'),
#  Text(0.40625, 0.1, 'squared_error = 40775705000.421\nsamples = 2617\nvalue = 648269.004'),
#  Text(0.46875, 0.1, 'squared_error = 237646234375.0\nsamples = 16\nvalue = 1856125.0'),
#  Text(0.75, 0.7, 'x[2] <= 4185.0\nsquared_error = 268351829992.673\nsamples = 3419\nvalue = 947373.07'),
#  Text(0.625, 0.5, 'x[13] <= 47.523\nsquared_error = 128831640766.249\nsamples = 2968\nvalue = 844723.018'),
#  Text(0.5625, 0.3, 'x[5] <= 0.5\nsquared_error = 43093987970.971\nsamples = 652\nvalue = 560001.202'),
#  Text(0.53125, 0.1, 'squared_error = 30992990588.391\nsamples = 637\nvalue = 545257.275'),
#  Text(0.59375, 0.1, 'squared_error = 155718364622.222\nsamples = 15\nvalue = 1186126.667'),
#  Text(0.6875, 0.3, 'x[10] <= 1975.5\nsquared_error = 123721860272.139\nsamples = 2316\nvalue = 924877.864'),
#  Text(0.65625, 0.1, 'squared_error = 184404764158.382\nsamples = 495\nvalue = 1186148.174'),
#  Text(0.71875, 0.1, 'squared_error = 83626943311.841\nsamples = 1821\nvalue = 853857.104'),
#  Text(0.875, 0.5, 'x[2] <= 7865.0\nsquared_error = 660836359472.659\nsamples = 451\nvalue = 1622906.011'),
#  Text(0.8125, 0.3, 'x[5] <= 0.5\nsquared_error = 543942490388.861\nsamples = 445\nvalue = 1584368.115'),
#  Text(0.78125, 0.1, 'squared_error = 456190730672.067\nsamples = 424\nvalue = 1522677.856'),
#  Text(0.84375, 0.1, 'squared_error = 687444663718.819\nsamples = 21\nvalue = 2829923.81'),
#  Text(0.9375, 0.3, 'x[1] <= 6.0\nsquared_error = 1050851488888.891\nsamples = 6\nvalue = 4481133.333'),
#  Text(0.90625, 0.1, 'squared_error = 35164586666.668\nsamples = 3\nvalue = 5343600.0'),
#  Text(0.96875, 0.1, 'squared_error = 578840888888.891\nsamples = 3\nvalue = 3618666.667')]

# %% [markdown]
# ### Redes neurais

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Gerando o normalizador
normalizer = preprocessing.Normalization()
normalizer.adapt(X_train.values)

# Criando o modelo com o normalizador e uma camada com um único perceptron

model = keras.Sequential([
    normalizer,
    layers.Dense(16),
    layers.Dense(12, activation='relu'),
    layers.Dense(7, activation='relu'),
    layers.Dense(5, activation='relu'),
    layers.Dense(1)
])

# Exibindo um resumo do modelo
model.summary()

# Configurando o modelo para utilizar o Adam durante gradiente descendente, utilizando erro quadrático médio para calculo de loss
model.compile(optimizer='adam', loss='mse')

# Treino com 100 épocas e 20% dos dados para calculo de loss
history = model.fit(
    X_train, y_train,
    epochs=100,
    validation_split=0.2,
    verbose=1
)

# Plotando o gráfico de loss para treino e teste com base na época
plot_loss(history)

# Teste
y_pred = model.predict(X_test).reshape(-1)

# Plotando gráfico dos valores de teste e dos valores previstos
plt.figure(figsize=(10,6))
plt.scatter(
    y_test,
    y_pred,
    color="blue",
    marker="o"
)
plt.plot(
    y_pred,
    y_pred,
    marker='o',
    color='green',
    markerfacecolor='red',
    markersize=7,
    linestyle='dashed'
)

plt.xlabel("Valores de teste")
plt.ylabel("Valores previstos")
plt.title("Valores previstos / teste")

plt.show()

# Visualizando a métrica R^2, quanto mais próximo de 1, melhor o ajuste do modelo aos dados
r2 = r2_score(y_test, y_pred)
print(f'R-squared (R²): {r2}')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_3 (Normaliza  (None, 16)                33
#  tion)
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 12)                204
#
#  dense_9 (Dense)             (None, 7)                 91
#
#  dense_10 (Dense)            (None, 5)                 40
#
#  dense_11 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 646 (2.53 KB)
# Trainable params: 613 (2.39 KB)
# Non-trainable params: 33 (136.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 433/433 [==============================] - 1s 2ms/step - loss: 410133790720.0000 - val_loss: 428191776768.0000
# Epoch 2/100
# 433/433 [==============================] - 1s 1ms/step - loss: 377948078080.0000 - val_loss: 325094637568.0000
# Epoch 3/100
# 433/433 [==============================] - 1s 1ms/step - loss: 201371303936.0000 - val_loss: 125717004288.0000
# Epoch 4/100
# 433/433 [==============================] - 1s 1ms/step - loss: 113517641728.0000 - val_loss: 111715295232.0000
# Epoch 5/100
# 433/433 [==============================] - 1s 1ms/step - loss: 108153184256.0000 - val_loss: 107624398848.0000
# Epoch 6/100
# 433/433 [==============================] - 1s 1ms/step - loss: 104915435520.0000 - val_loss: 104308531200.0000
# Epoch 7/100
# 433/433 [==============================] - 1s 1ms/step - loss: 101902483456.0000 - val_loss: 101340708864.0000
# Epoch 8/100
# 433/433 [==============================] - 1s 1ms/step - loss: 98982592512.0000 - val_loss: 98386427904.0000
# Epoch 9/100
# 433/433 [==============================] - 1s 1ms/step - loss: 96017268736.0000 - val_loss: 95445327872.0000
# Epoch 10/100
# 433/433 [==============================] - 1s 1ms/step - loss: 92675350528.0000 - val_loss: 92247007232.0000
# Epoch 11/100
# 433/433 [==============================] - 1s 1ms/step - loss: 88936357888.0000 - val_loss: 88094752768.0000
# Epoch 12/100
# 433/433 [==============================] - 1s 1ms/step - loss: 84086702080.0000 - val_loss: 83074203648.0000
# Epoch 13/100
# 433/433 [==============================] - 1s 1ms/step - loss: 77858004992.0000 - val_loss: 76226469888.0000
# Epoch 14/100
# 433/433 [==============================] - 1s 1ms/step - loss: 69905440768.0000 - val_loss: 68295966720.0000
# Epoch 15/100
# 433/433 [==============================] - 1s 1ms/step - loss: 61344161792.0000 - val_loss: 60697251840.0000
# Epoch 16/100
# 433/433 [==============================] - 1s 1ms/step - loss: 53950926848.0000 - val_loss: 54818484224.0000
# Epoch 17/100
# 433/433 [==============================] - 1s 1ms/step - loss: 48557907968.0000 - val_loss: 50541764608.0000
# Epoch 18/100
# 433/433 [==============================] - 1s 1ms/step - loss: 44657602560.0000 - val_loss: 47253032960.0000
# Epoch 19/100
# 433/433 [==============================] - 1s 1ms/step - loss: 41690845184.0000 - val_loss: 44879798272.0000
# Epoch 20/100
# 433/433 [==============================] - 1s 1ms/step - loss: 39557091328.0000 - val_loss: 43009454080.0000
# Epoch 21/100
# 433/433 [==============================] - 1s 2ms/step - loss: 37990989824.0000 - val_loss: 42029608960.0000
# Epoch 22/100
# 433/433 [==============================] - 1s 1ms/step - loss: 37001805824.0000 - val_loss: 40893444096.0000
# Epoch 23/100
# 433/433 [==============================] - 1s 1ms/step - loss: 36223266816.0000 - val_loss: 40214073344.0000
# Epoch 24/100
# 433/433 [==============================] - 1s 1ms/step - loss: 35688710144.0000 - val_loss: 39715094528.0000
# Epoch 25/100
# 433/433 [==============================] - 1s 1ms/step - loss: 35264598016.0000 - val_loss: 39336931328.0000
# Epoch 26/100
# 433/433 [==============================] - 1s 1ms/step - loss: 34967343104.0000 - val_loss: 39059341312.0000
# Epoch 27/100
# 433/433 [==============================] - 1s 1ms/step - loss: 34695004160.0000 - val_loss: 38823145472.0000
# Epoch 28/100
# 433/433 [==============================] - 1s 1ms/step - loss: 34470969344.0000 - val_loss: 38680903680.0000
# Epoch 29/100
# 433/433 [==============================] - 1s 1ms/step - loss: 34308608000.0000 - val_loss: 38465204224.0000
# Epoch 30/100
# 433/433 [==============================] - 1s 1ms/step - loss: 34161707008.0000 - val_loss: 38206251008.0000
# Epoch 31/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33972523008.0000 - val_loss: 38022414336.0000
# Epoch 32/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33850836992.0000 - val_loss: 37861187584.0000
# Epoch 33/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33668411392.0000 - val_loss: 37703184384.0000
# Epoch 34/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33562648576.0000 - val_loss: 37622706176.0000
# Epoch 35/100
# 433/433 [==============================] - 0s 1ms/step - loss: 33422858240.0000 - val_loss: 37420707840.0000
# Epoch 36/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33254780928.0000 - val_loss: 37242519552.0000
# Epoch 37/100
# 433/433 [==============================] - 1s 1ms/step - loss: 33092745216.0000 - val_loss: 37214666752.0000
# Epoch 38/100
# 433/433 [==============================] - 0s 1ms/step - loss: 32993155072.0000 - val_loss: 36966879232.0000
# Epoch 39/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32854403072.0000 - val_loss: 36854554624.0000
# Epoch 40/100
# 433/433 [==============================] - 0s 1ms/step - loss: 32767449088.0000 - val_loss: 36695265280.0000
# Epoch 41/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32656388096.0000 - val_loss: 36584861696.0000
# Epoch 42/100
# 433/433 [==============================] - 0s 1ms/step - loss: 32543252480.0000 - val_loss: 36476010496.0000
# Epoch 43/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32431523840.0000 - val_loss: 36411232256.0000
# Epoch 44/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32325695488.0000 - val_loss: 36272111616.0000
# Epoch 45/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32215891968.0000 - val_loss: 36230250496.0000
# Epoch 46/100
# 433/433 [==============================] - 0s 1ms/step - loss: 32154247168.0000 - val_loss: 36085669888.0000
# Epoch 47/100
# 433/433 [==============================] - 1s 1ms/step - loss: 32055900160.0000 - val_loss: 35997528064.0000
# Epoch 48/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31988168704.0000 - val_loss: 35936862208.0000
# Epoch 49/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31911860224.0000 - val_loss: 35795210240.0000
# Epoch 50/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31831261184.0000 - val_loss: 35718905856.0000
# Epoch 51/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31785998336.0000 - val_loss: 35603296256.0000
# Epoch 52/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31687016448.0000 - val_loss: 35570860032.0000
# Epoch 53/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31606235136.0000 - val_loss: 35503329280.0000
# Epoch 54/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31501393920.0000 - val_loss: 35437465600.0000
# Epoch 55/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31489404928.0000 - val_loss: 35372232704.0000
# Epoch 56/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31426312192.0000 - val_loss: 35213910016.0000
# Epoch 57/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31363188736.0000 - val_loss: 35148705792.0000
# Epoch 58/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31317024768.0000 - val_loss: 35097972736.0000
# Epoch 59/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31260428288.0000 - val_loss: 35031146496.0000
# Epoch 60/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31186976768.0000 - val_loss: 34998755328.0000
# Epoch 61/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31154896896.0000 - val_loss: 34921172992.0000
# Epoch 62/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31095627776.0000 - val_loss: 34842079232.0000
# Epoch 63/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31043123200.0000 - val_loss: 34826678272.0000
# Epoch 64/100
# 433/433 [==============================] - 1s 1ms/step - loss: 31033329664.0000 - val_loss: 34735026176.0000
# Epoch 65/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30951444480.0000 - val_loss: 34720124928.0000
# Epoch 66/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30889900032.0000 - val_loss: 34745229312.0000
# Epoch 67/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30856820736.0000 - val_loss: 34661720064.0000
# Epoch 68/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30827765760.0000 - val_loss: 34555711488.0000
# Epoch 69/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30788069376.0000 - val_loss: 34522808320.0000
# Epoch 70/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30747138048.0000 - val_loss: 34457260032.0000
# Epoch 71/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30732398592.0000 - val_loss: 34478821376.0000
# Epoch 72/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30721320960.0000 - val_loss: 34370383872.0000
# Epoch 73/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30631524352.0000 - val_loss: 34344628224.0000
# Epoch 74/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30578159616.0000 - val_loss: 34287446016.0000
# Epoch 75/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30547111936.0000 - val_loss: 34267717632.0000
# Epoch 76/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30517153792.0000 - val_loss: 34212478976.0000
# Epoch 77/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30495135744.0000 - val_loss: 34189639680.0000
# Epoch 78/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30434490368.0000 - val_loss: 34178543616.0000
# Epoch 79/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30397655040.0000 - val_loss: 34186577920.0000
# Epoch 80/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30413539328.0000 - val_loss: 34111645696.0000
# Epoch 81/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30342195200.0000 - val_loss: 34173988864.0000
# Epoch 82/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30351822848.0000 - val_loss: 34043242496.0000
# Epoch 83/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30372292608.0000 - val_loss: 33994799104.0000
# Epoch 84/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30307078144.0000 - val_loss: 34009942016.0000
# Epoch 85/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30286594048.0000 - val_loss: 33936797696.0000
# Epoch 86/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30274054144.0000 - val_loss: 33957070848.0000
# Epoch 87/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30229858304.0000 - val_loss: 33881319424.0000
# Epoch 88/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30211248128.0000 - val_loss: 33871704064.0000
# Epoch 89/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30225813504.0000 - val_loss: 33834727424.0000
# Epoch 90/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30161770496.0000 - val_loss: 33792546816.0000
# Epoch 91/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30170552320.0000 - val_loss: 33883006976.0000
# Epoch 92/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30189598720.0000 - val_loss: 33759379456.0000
# Epoch 93/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30127302656.0000 - val_loss: 33735233536.0000
# Epoch 94/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30106177536.0000 - val_loss: 33712187392.0000
# Epoch 95/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30095579136.0000 - val_loss: 33741312000.0000
# Epoch 96/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30125492224.0000 - val_loss: 33675710464.0000
# Epoch 97/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30051862528.0000 - val_loss: 33848004608.0000
# Epoch 98/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30063253504.0000 - val_loss: 33680246784.0000
# Epoch 99/100
# 433/433 [==============================] - 1s 1ms/step - loss: 29996660736.0000 - val_loss: 33668823040.0000
# Epoch 100/100
# 433/433 [==============================] - 1s 1ms/step - loss: 30078533632.0000 - val_loss: 33590001664.0000
# 136/136 [==============================] - 0s 858us/step
# R-squared (R²): 0.7603858319633304

# %% [markdown]
# # Conclusões sobre os modelos

# %% [markdown]
# A preencher
